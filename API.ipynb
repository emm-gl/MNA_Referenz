# %% [markdown]
# <a href="https://colab.research.google.com/github/emm-gl/MNA_Referenz/blob/main/API.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import pandas as pd

#URLs
url_ordenes = 'https://api.backendless.com/69DA66B9-D1A8-C396-FF6B-10897D65A600/DBA10B8A-452F-4D8D-AE29-C1A70D9B2CA5/data/Ordenes'
url_clientes = 'https://api.backendless.com/69DA66B9-D1A8-C396-FF6B-10897D65A600/DBA10B8A-452F-4D8D-AE29-C1A70D9B2CA5/data/Clientes'
url_productos = 'https://api.backendless.com/69DA66B9-D1A8-C396-FF6B-10897D65A600/DBA10B8A-452F-4D8D-AE29-C1A70D9B2CA5/data/Productos'

# %% [markdown]
# ### Get

# %% [markdown]
# Si logran hacer con la API que pueda enviar la lista de todos los productos que compró el cliente en un solo POST

# %% [markdown]
# #Obtener número de cliente (IdCliente):

# %%
cliente = 'Emmanuel González'     # Info que llega desde el frontend

response = requests.get(url_clientes)
df_clientes = pd.DataFrame(response.json())
df_clientes
# Out:
#    IdCliente       NombreCliente        created  ___class ownerId updated  \
# 0       8804         Pedro Ortiz  1699456526033  Clientes    None    None
# 1       7705       Adriana Vidal  1699456551567  Clientes    None    None
# 2       6608          Paco Duran  1699456572998  Clientes    None    None
# 3       9905   Emmanuel González  1699456502673  Clientes    None    None
# 4       6348  Cumbres, Monterrey  1699456590314  Clientes    None    None
#
#                       DireccionCliente                              objectId
# 0         Punto Valle, San Pedro Garza  503EF72D-1F9D-4F07-8E38-3E62138DF87F
# 1  La Fuente, San Nicolas de los Garza  83F90F73-A2D4-4C68-90AD-497B99190201
# 2                El Mirador, Guadalupe  882173C4-8CF9-4BCE-B333-C2145323D25C
# 3      Balcones del Mirador, Monterrey  9BC1A92C-2E9A-432E-A2C3-8A0250D8B459
# 4                       Brenda Miranda  A1564C0B-14D2-4404-A9C0-DDC23B571E2E

# %%
filtro = df_clientes['NombreCliente'] == cliente
resultados_filtrados = df_clientes[filtro]
resultados_filtrados
# Out:
#    IdCliente      NombreCliente        created  ___class ownerId updated  \
# 3       9905  Emmanuel González  1699456502673  Clientes    None    None
#
#                   DireccionCliente                              objectId
# 3  Balcones del Mirador, Monterrey  9BC1A92C-2E9A-432E-A2C3-8A0250D8B459

# %%
IdCliente_ = resultados_filtrados.iloc[0,0]
print(IdCliente_)
# Out:
# 9905

# %% [markdown]
# # Lista de todos los productos que compró el cliente:

# %%
response = requests.get(url_ordenes)
df_ordenes = pd.DataFrame(response.json())
df_ordenes
# Out:
#    IdCliente          Fecha  Cantidad        created query ___class  \
# 0       9905  1699379226000        11  1699465638600  None  Ordenes
# 1       6608  1699457807000        15  1699457820643  None  Ordenes
# 2       9905  1697522400000         3  1699465665567  None  Ordenes
# 3       6348  1699457847000         9  1699457866189  None  Ordenes
# 4       9905  1699457601000         5  1699457620122  None  Ordenes
# 5       7705  1699457775000         1  1699457789509  None  Ordenes
# 6       8804  1699457750000         8  1699457761908  None  Ordenes
#
#    IdProducto ownerId       updated                              objectId
# 0        7896    None           NaN  1FD1BF1C-C2F9-47C0-A0CC-452318AD2663
# 1        7896    None           NaN  2B560D4F-B4B4-4E8B-AB27-0D5FF25424C6
# 2        3021    None           NaN  8EF2A756-D42C-425D-BA2F-F80678304E2A
# 3        3021    None           NaN  A7EE16A0-DB9E-4F5C-8055-923FB53550F3
# ...

# %%
filtro_PorCliente = df_ordenes['IdCliente'] == IdCliente_
resultados_filtrados_ordenes = df_ordenes[filtro_PorCliente]
resultados_filtrados_ordenes
# Out:
#    IdCliente          Fecha  Cantidad        created query ___class  \
# 0       9905  1699379226000        11  1699465638600  None  Ordenes
# 2       9905  1697522400000         3  1699465665567  None  Ordenes
# 4       9905  1699457601000         5  1699457620122  None  Ordenes
#
#    IdProducto ownerId       updated                              objectId
# 0        7896    None           NaN  1FD1BF1C-C2F9-47C0-A0CC-452318AD2663
# 2        3021    None           NaN  8EF2A756-D42C-425D-BA2F-F80678304E2A
# 4         789    None  1.699458e+12  C7136B32-D6D1-4E28-9009-E445F81DFC17
